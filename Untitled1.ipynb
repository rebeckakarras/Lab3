# %%
from lab import run_experiment

# %%
import pandas as pd
import numpy as np
from numpy.random import rand

# %%
T = 30.1 #degrees
c = 1.9 * 10**(-3) #mol
run_experiment(T,c)
# Out:
# 3.186500088836696

# %% [markdown]
# 2-Level factorial design basis
# Choosing a high and a low value
# T_high = 40
# T_low = 20
# c_high = 3 mmol
# c_low = 1 mmol
# with 30.1 and 1.9 mmol as my centerpoints.

# %%
inputs_labels = {'A' : 'Temperature',
                 'B' : 'Concentration',
                 }

dat = [('A',25,40),
       ('B',1.5*10**(-3),3*10**(-3)),
     ]

inputs_df = pd.DataFrame(dat,columns=['index','low','high'])
inputs_df = inputs_df.set_index(['index'])
inputs_df['label'] = inputs_df.index.map( lambda z : inputs_labels[z] )

inputs_df
# Out:
#            low    high          label
# index
# A      25.0000  40.000    Temperature
# B       0.0015   0.003  Concentration

# %%
inputs_df['average'] = inputs_df.apply( lambda z : ( z['high'] + z['low'])/2 , axis=1)
inputs_df['span'] = inputs_df.apply( lambda z : ( z['high'] - z['low'])/2 , axis=1)

inputs_df['encoded_low'] = inputs_df.apply( lambda z : ( z['low']  - z['average'] )/( z['span'] ), axis=1)
inputs_df['encoded_high'] = inputs_df.apply( lambda z : ( z['high'] - z['average'] )/( z['span'] ), axis=1)

inputs_df = inputs_df.drop(['average','span'],axis=1)

inputs_df
# Out:
#            low    high          label  encoded_low  encoded_high
# index
# A      25.0000  40.000    Temperature         -1.0           1.0
# B       0.0015   0.003  Concentration         -1.0           1.0

# %%
import itertools
# we have four repetitions
encoded_inputs= list(itertools.product([-1,1],[-1,1]))
encoded_inputs
# Out:
# [(-1, -1), (-1, 1), (1, -1), (1, 1)]

# %%
def decode_input(encoded_input, inputs_df):
    decoded_values = []
    for idx, val in enumerate(encoded_input):
        if val == -1:
            decoded_values.append(inputs_df.iloc[idx]['low'])
        else:
            decoded_values.append(inputs_df.iloc[idx]['high'])
    return decoded_values

# Apply the decoding function to each encoded input
decoded_experiments = [decode_input(encoded_input, inputs_df) for encoded_input in encoded_inputs]

# Create a new DataFrame with the decoded values
decoded_df = pd.DataFrame(decoded_experiments, columns=inputs_labels)
decoded_df.head()
# Out:
#       A       B
# 0  25.0  0.0015
# 1  25.0  0.0030
# 2  40.0  0.0015
# 3  40.0  0.0030

# %%
#orginal data
results = []
for T,c in decoded_experiments:
  Result = run_experiment(T,c)
  results.append(Result)

resultsorg = pd.DataFrame(results, columns=["y1"])
resultsorg
# Out:
#          y1
# 0  0.222428
# 1  0.222500
# 2  4.252079
# 3  4.254810

# %%
import pandas as pd
import itertools
import random

# Define your inputs_df (example)
#inputs_df = pd.DataFrame({
  #  'parameter': ['T', 'c'],
 #   'low': [20.0, 1.0e-3],
   # 'high': [40.0, 3.0e-3]
#})

# Center values for T and c (adjust these as needed)
center_T = 30.1  # Example center temperature
center_c = 1.9 * 10**(-3)  # Example center concentration

# Generate encoded inputs
encoded_inputs = list(itertools.product([-1, 1], [-1, 1]))

# Define the decode_input function
def decode_input(encoded_input, inputs_df):
    decoded_values = []
    for idx, val in enumerate(encoded_input):
        if val == -1:
            decoded_values.append(inputs_df.iloc[idx]['low'])
        else:
            decoded_values.append(inputs_df.iloc[idx]['high'])
    return decoded_values

# Decode the values for each encoded input
decoded_experiments = [decode_input(encoded_input, inputs_df) for encoded_input in encoded_inputs]

# Initialize results list
generated_data = []
row_resalts = []
# Number of repetitions for each encoded input
num_repetitions = 1

# Loop through each encoded input
for encoded_input in encoded_inputs:
    # Decode to get base values
    low_T, high_T = inputs_df.iloc[0]['low'], inputs_df.iloc[0]['high']
    low_c, high_c = inputs_df.iloc[1]['low'], inputs_df.iloc[1]['high']

    # Decode the current encoded input to get the low or high value
    T_decoded, c_decoded = decode_input(encoded_input, inputs_df)

    # Generate matching values multiple times
    for _ in range(num_repetitions):
        # Randomize T based on whether it is decoded to low or high
        if T_decoded == low_T:
            # Randomize a value below center_T
            T_randomized = random.uniform(low_T, center_T)
        else:
            # Randomize a value above center_T
            T_randomized = random.uniform(center_T, high_T)

        # Randomize c based on whether it is decoded to low or high
        if c_decoded == low_c:
            # Randomize a value below center_c
            c_randomized = random.uniform(low_c, center_c)
        else:
            # Randomize a value above center_c
            c_randomized = random.uniform(center_c, high_c)

        # Append generated data to the list (T_randomized, c_randomized, and encoded_input)
        Result = run_experiment(T_randomized, c_randomized)  # Run the experiment with these values
        generated_data.append((T_randomized, c_randomized, Result))

# Convert generated data to a DataFrame for better organization
generated_data_df = pd.DataFrame(generated_data, columns=['T', 'c', 'y1'])

# Display the generated values
print(generated_data_df)
# Out:
#            T         c   Results
# 0  25.503739  0.001600  0.328452
# 1  25.290672  0.002560  0.279543
# 2  39.884452  0.001644  4.304017
# 3  31.219840  0.002937  3.949626

# %%
results = []

# Iterate over the generated data and run the experiment
for i in range(2):
    for _, row in generated_data_df.iterrows():
       T = row['T']  # Extract randomized T
       c = row['c']  # Extract randomized c
       Result = run_experiment(T, c)  # Run the experiment with these values
       row_results = []

       Result = run_experiment(T, c)  # Run the experiment with these values
       row_results.append(Result)
       results.append(row_results)  # Append the list of results for this row

# Convert results to a DataFrame with dynamically generated column names

results_df = pd.DataFrame(results, columns=[f'y{i+1}' for i in range(2)])

# Merge the original input data with the results
final_df = pd.concat([generated_data_df, results_df], axis=1)
results.append(Result)  # Store the result
# Convert results to a DataFrame
final_df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     938     try:
# --> 939         columns = _validate_or_indexify_columns(contents, columns)
#     940     except AssertionError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _validate_or_indexify_columns(content, columns)
#     985             # caller's responsibility to check for this...
# --> 986             raise AssertionError(
#     987                 f"{len(columns)} columns passed, passed data had "
#
# AssertionError: 2 columns passed, passed data had 1 columns
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-93-a628b3e91538> in <cell line: 17>()
#      15 # Convert results to a DataFrame with dynamically generated column names
#      16
# ---> 17 results_df = pd.DataFrame(results, columns=[f'y{i+1}' for i in range(2)])
#      18
#      19 # Merge the original input data with the results
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     804                     if columns is not None:
#     805                         columns = ensure_index(columns)
# --> 806                     arrays, columns, index = nested_data_to_arrays(
#     807                         # error: Argument 3 to "nested_data_to_arrays" has incompatible
#     808                         # type "Optional[Collection[Any]]"; expected "Optional[Index]"
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in nested_data_to_arrays(data, columns, index, dtype)
#     518         columns = ensure_index(data[0]._fields)
#     519
# --> 520     arrays, columns = to_arrays(data, columns, dtype=dtype)
#     521     columns = ensure_index(columns)
#     522
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in to_arrays(data, columns, dtype)
#     843         arr = _list_to_arrays(data)
#     844
# --> 845     content, columns = _finalize_columns_and_data(arr, columns, dtype)
#     846     return content, columns
#     847
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _finalize_columns_and_data(content, columns, dtype)
#     940     except AssertionError as err:
#     941         # GH#26429 do not raise user-facing AssertionError
# --> 942         raise ValueError(err) from err
#     943
#     944     if len(contents) and contents[0].dtype == np.object_:
#
# ValueError: 2 columns passed, passed data had 1 columns

# %%
combined_output = pd.concat([decoded_df, resultsorg, results_df], axis=1)
combined_output
# Out:
#       A       B        y1        y2
# 0  25.0  0.0015  0.222428  1.171867
# 1  25.0  0.0030  0.222500  2.775152
# 2  40.0  0.0015  4.252079  4.280161
# 3  40.0  0.0030  4.254810  4.201915

# %%
output=pd.DataFrame(encoded_inputs,columns=['A','B'])
result_1 = results[0]  # T_low, c_low
result_2 = results[1]  # T_low, c_high
result_3 = results[2]  # T_high, c_low
result_4 = results[3]  # T_high, c_high
data = pd.DataFrame(results, columns=['mol/s'])
combined_output = pd.concat([decoded_df, output, data], axis=1)
combined_output
# Out:
#       A       B  A  B     mol/s
# 0  25.0  0.0015 -1 -1  1.171867
# 1  25.0  0.0030 -1  1  2.775152
# 2  40.0  0.0015  1 -1  4.280161
# 3  40.0  0.0030  1  1  4.201915

# %%
main_effect_T = ((result_3 + result_4) / 2) - ((result_1 + result_2) / 2)  # Effect of Temperature
main_effect_c = ((result_2 + result_4) / 2) - ((result_1 + result_3) / 2)  # Effect of Concentration

# Interaction effect
interaction_effect = (result_4 - result_3 - result_2 + result_1) / 4
